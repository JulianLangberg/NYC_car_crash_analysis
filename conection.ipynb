# %%
from databricks import sql
import pandas as pd

# %%
def tabla(db,tabla):
    connection =  sql.connect(server_hostname = 'dbc-156e0dba-cc88.cloud.databricks.com',
                              http_path       = 'sql/protocolv1/o/3085278994866805/0907-021244-iq24n037',
                              access_token    = 'dapi400119482528a0aceea05ccffcedcc59')

    cursor = connection.cursor()
    cursor.execute(f"SELECT * FROM {db}.{tabla}")
    result = cursor.fetchall()
    df = pd.DataFrame(result)
    cursor.close()
    connection.close()
    return df

# %%
df = tabla(silver, ny_city_data)

# %%
df
# Out:
#            0                               1                              2   \
# 0     4547589                Backing Unsafely                    Unspecified
# 1     4548075                    Unsafe Speed                    Unspecified
# 2     4407480           Following Too Closely                    Unspecified
# 3     4407147                     Unspecified                           None
# 4     4407665               Pavement Slippery                           None
# ...       ...                             ...                            ...
# 9995  4551470  Driver Inattention/Distraction  Failure to Yield Right-of-Way
# 9996  4551539                     Unspecified                           None
# 9997  4551347  Driver Inattention/Distraction                    Unspecified
# 9998  4551018                     Fell Asleep                    Unspecified
# 9999  4551398                    Unsafe Speed                    Unspecified
#
# ...

# %%
class coso():
    def __init__(self,endpoint,tabla):
        self.endpoint = endpoint
        self.table = tabla

# %%
coso = coso('hola','mundo')

# %%
coso.endpoint
# Out:
# 'hola'
